# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn.datasets
import matplotlib

# %%
'''
Funciton: plot_decision_boundary
Usage: 
    Draw the boundary of the prediction function 
    on the dataset with features X and labels y 
parameter: 
    X: features of dataset
    y: labels of dataset
    pred_func: prediction function
Example:
    plot_decision_boundary(X, y, lambda x: model.predict(x))
    plt.title("3 Hidden Layer")
'''
def plot_decision_boundary(X, y, pred_func):
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %%
'''
Show the dataset I used from sklearn
'''
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
np.random.seed(0)
X, y = sklearn.datasets.make_moons(200, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)

# %%
'''
Some Activation function
But only _tanh is used now
'''
def _tanh(x):
    return np.tanh(x)

def _ReLU(x):
    return x*(x > 0)

def _sigmoid(x):
    return 1 / (1 + np.exp(-x))

'''
Softmax function for classification
'''
def _softmax(A):
    expA = np.exp(A)
    return expA / expA.sum(axis=1, keepdims=True)

# %%
class NNmodel:
    '''
    Function: __init__
    Usage:
        Generate a Neural Network model
    Parameter:
        X: features of dataset
        y: labels of dataset
        inputDim: dimension of input layer
        outputDim: dimension of output layer
        epsilon: learning rate
        regLambda: regularization rate
    Example:
        model = NNmodel(X,y,2,2,0.01,0.01)
    '''
    def __init__(self, X, y, inputDim=2, outputDim=2, epsilon=0.01, regLambda=0.01):
        self.X = X
        self.y = y
        self._inputDim = inputDim
        self._outputDim = outputDim
        self.size = X.shape[0]
        self.epsilon = epsilon
        self.regLambda = regLambda
        
        self.param = {"W1":0, "b1":0, "W2":0, "b2": 0}
        self.activation = "tanh"
        self._activation_list = ["tanh", "sigmoid"]
        
    def activate(self, x):
        if (self.activation == "tanh"):
            return _tanh(x)
        elif (self.activation == "sigmoid"):
            return _sigmoid(x)
        elif (self.activation == "ReLU"):
            return _ReLU(x)
        
    def get_parameter(self):
        return self.param["W1"], self.param["b1"], self.param["W2"], self.param["b2"]
    
    def calculate_loss(self):
        return self.cross_entropy()
    
    '''
    Function: cross_entropy
    Usage:
        Use cross entropy as the loss function
    Parameter:
        None
    Example:
        loss = self.cross_entropy()
    '''
    def cross_entropy(self):
        W1, b1, W2, b2 = self.get_parameter()
        # FP
        z1 = self.X.dot(W1) + b1
        a1 = self.activate(z1)
        z2 = a1.dot(W2) + b2
        a2 = _softmax(z2)
        logProbs = -np.log(a2[range(self.size), self.y])
        loss = np.sum(logProbs)
        loss += self.regLambda/2 * (np.sum(np.square(W1)) + np.sum(np.square(W2))) #Regularization
        return 1./self.size * loss

    '''
    Function: predict
    Usage:
        Predict the result
    Parameter:
        x: features of data
    Example:
        result = model.predict(x)
    '''
    def predict(self, x):
        W1, b1, W2, b2 = self.get_parameter()
        # FP
        z1 = x.dot(W1) + b1
        a1 = self.activate(z1)
        z2 = a1.dot(W2) + b2
        a2 = _softmax(z2)
        return np.argmax(a2, axis=1)
    
    '''
    Function: build_model
    Usage:
        Build the NN model
    Parameter:
        hiddenDim: dimension of the hidden layer
        passes: number of iteration
        print_loss: whether to print the loss and accuracy when training
        activation: activation function
    Example:
        model.build_model(5, activation="sigmoid")
    '''
    def build_model(self, hiddenDim, passes=20000, print_loss=False, activation="tanh"):
        if (activation not in self._activation_list):
            return None
        self.activation = activation

        np.random.seed(0)
        W1 = np.random.randn(self._inputDim, hiddenDim) / np.sqrt(self._inputDim)
        b1 = np.zeros((1, hiddenDim))
        W2 = np.random.randn(hiddenDim, self._outputDim) / np.sqrt(hiddenDim)
        b2 = np.zeros((1, self._outputDim))
        self.param = {"W1":W1, "b1":b1, "W2":W2, "b2":b2}

        for i in range(0, passes):
            if (self.activation == "tanh"):
                # FP
                z1 = self.X.dot(W1) + b1
                a1 = self.activate(z1)
                z2 = a1.dot(W2) + b2
                a2 = _softmax(z2)

                # BP
                delta3 = probs
                delta3[range(self.size), self.y] -= 1
                delta2 = delta3.dot(W2.T) * (1 - np.power(a1, 2))
                dW2 = (a1.T).dot(delta3)
                db2 = np.sum(delta3, axis=0, keepdims=True)
                dW1 = np.dot(self.X.T, delta2)
                db1 = np.sum(delta2, axis=0)
                
                # Regularization
                dW2 += self.regLambda * W2
                dW1 += self.regLambda * W1

                W1 += -self.epsilon * dW1
                b1 += -self.epsilon * db1
                W2 += -self.epsilon * dW2
                b2 += -self.epsilon * db2
            elif (self.activation == "sigmoid"):
                # FP
                z1 = self.X.dot(W1) + b1
                a1 = self.activate(z1)
                z2 = a1.dot(W2) + b2
                a2 = _softmax(z2)

                # BP
                delta3 = a2
                delta3[range(self.size), self.y] -= 1 # delta3 = y' - y
                delta2 = (delta3).dot(W2.T) * a1 * (1 - a1)
                
                dW2 = a1.T.dot(delta3)
                db2 = (delta3).sum(axis=0)
                dW1 = self.X.T.dot(delta2)
                db1 = (delta2).sum(axis=0)
                
                # Regularization
                dW2 += self.regLambda * W2
                dW1 += self.regLambda * W1
        
                W2 += -self.epsilon * dW2
                b2 += -self.epsilon * db2
                W1 += -self.epsilon * dW1
                b1 += -self.epsilon * db1
                
            
            self.param = {"W1":W1, "b1":b1, "W2":W2, "b2":b2}

            if print_loss and i % 2000 == 0:
                correct = 0
                for j, data in enumerate(self.X):
                    if (self.predict(data) == self.y[j]):
                        correct += 1
                print("Accuracy after iteration %i: %f" %(i, correct/self.size))
                print("Loss after iteration %i: %f" %(i, self.calculate_loss()))

# %%
model = NNmodel(X, y, inputDim=2, outputDim=2)
model.build_model(3, print_loss=False,activation=activation)
plot_decision_boundary(X, y, lambda x: model.predict(x))
plt.title("3 Hidden Layer")
# Out:
# Text(0.5,1,'3 Hidden Layer')

# %%
plt.figure(figsize=(16, 32))
activations = ["tanh", "sigmoid"]
model = NNmodel(X, y, inputDim=2, outputDim=2)
for i, activation in enumerate(activations):
    plt.subplot(5, 2, i+1)
    plt.title('Activation: %s' % activation)
    model.build_model(3, print_loss=False,activation=activation)
    plot_decision_boundary(X, y, lambda x: model.predict(x))
plt.show()

# %%
plt.figure(figsize=(16, 32))
hiddenLayers = [1, 2, 3, 4, 5, 20, 50]
for i, nn_hdim in enumerate(hiddenLayers):
    plt.subplot(5, 2, i+1)
    plt.title('%d Hidden Layer' % nn_hdim)
    model.build_model(nn_hdim, print_loss=False)
    plot_decision_boundary(X, y, lambda x: model.predict(x))
plt.show()

# %%
import pandas as pd

# %%
# Use the dataset from https://archive.ics.uci.edu/ml/datasets/Iris
data = pd.read_csv('iris.data',sep=",",header=None)
df = pd.DataFrame(data)
df.columns=['sepal length','sepal width','petal length','petal width','class']
df = df.sample(frac=1).reset_index(drop=True)
df[0:5] # Preview of the dataset
# Out:
#    sepal length  sepal width  petal length  petal width            class
# 0           6.1          2.8           4.7          1.2  Iris-versicolor
# 1           5.4          3.9           1.3          0.4      Iris-setosa
# 2           6.5          3.0           5.8          2.2   Iris-virginica
# 3           5.1          3.5           1.4          0.3      Iris-setosa
# 4           5.9          3.0           4.2          1.5  Iris-versicolor

# %%
training_X = df.loc[:,['sepal length','sepal width','petal length','petal width']]
training_Y = df.loc[:,'class']
training_X = training_X.values
training_Y = training_Y.values
training_Y = np.squeeze(training_Y)

# %%
training_Y[training_Y=='Iris-setosa']=0
training_Y[training_Y=='Iris-versicolor']=1
training_Y[training_Y=='Iris-virginica']=2
training_Y = training_Y.astype(int)

# %%
from sklearn import preprocessing
X_scaled = preprocessing.scale(training_X)

# %%
another_model = NNmodel(X_scaled, training_Y, inputDim=4, outputDim=3)

# %%
another_model.build_model(hiddenDim=5, passes=4000, print_loss=True, activation="sigmoid")
# Out:
# Accuracy after iteration 0: 0.540000
# Loss after iteration 0: 0.946592
# Accuracy after iteration 2000: 0.986667
# Loss after iteration 2000: 0.047941
